# %%
import numpy as np

# Dataset
X = np.array([
    [2, 60],
    [3, 65],
    [4, 70],
    [5, 75],
    [6, 80],
    [7, 85]
])

y = np.array([0, 0, 0, 1, 1, 1])


# Initial weights and bias
weights = np.array([0.5, 0.5])
bias = 0

# %%
learning_rate = 0.01

# %%
weight = np.array([0.5,0.5])
bias = 0

# %%
def step_function(z):
    if z >= 0:
        return 1
    else:
        return 0


# Take first student
x = X[0]
actual = y[0]

# %%
z = np.dot(x, weights) + bias

# Prediction
prediction = step_function(z)

# Calculate error
error = actual - prediction

print("Weighted Sum:", z)
print("Prediction:", prediction)
print("Actual:", actual)
print("Error:", error)


# Update weights and bias
weights = weights + learning_rate * error * x
bias = bias + learning_rate * error

print("Updated Weights:", weights)
print("Updated Bias:", bias)
# Out:
# Weighted Sum: 31.0
# Prediction: 1
# Actual: 0
# Error: -1
# Updated Weights: [ 0.48 -0.1 ]
# Updated Bias: -0.01

# %% [markdown]
# # Using tensorflow

# %%
import tensorflow as tf

# %%
import numpy as np

X = np.array([
    [2, 60],
    [3, 65],
    [4, 70],
    [5, 75],
    [6, 80],
    [7, 85]
], dtype=np.float32)

y = np.array([0, 0, 0, 1, 1, 1], dtype=np.float32)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1,activation='sigmoid')
])

# %%
model.compile(
    optimizer = 'sgd',
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)

# %%
model.fit(X, y, epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5000 - loss: 24.5640
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.5000 - loss: 13.9765
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5000 - loss: 3.3917
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5000 - loss: 10.1988
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.5000 - loss: 5.9175
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5000 - loss: 7.1537
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5000 - loss: 8.3758
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5000 - loss: 4.1206
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5000 - loss: 10.6429
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.1667 - loss: 1.7563
